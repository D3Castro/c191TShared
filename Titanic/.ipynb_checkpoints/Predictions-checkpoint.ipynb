# %%
# To support both python 2 and python 3
from __future__ import division, print_function, unicode_literals

# Common imports
import numpy as np
import os

# to make this notebook's output stable across runs
np.random.seed(42)

# To plot pretty figures
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

import pandas as pd

from sklearn.base import clone
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split, StratifiedKFold

import string

# Import datasets
df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')

# %% [markdown]
# <h1><b>HELPFUL FEATURES</b></h1>

# %%
#New features that may help 

#Modified Kaggle Function
def substrings_in_string(big_string, substrings):
    for substring in substrings:
        if big_string.startswith(substring):
            return substring
    return np.nan

#Kaggle Function: Turning cabin number into Deck
cabin_list = ['A', 'B', 'C', 'D', 'E', 'F', 'T', 'G', 'Unknown']
df_train['Deck']=df_train['Cabin'].map(lambda x: substrings_in_string(str(x), cabin_list))
df_test['Deck']=df_test['Cabin'].map(lambda x: substrings_in_string(str(x), cabin_list))

#Kaggle Function: Family_size column
df_train['FamilySize']=df_train['SibSp']+df_train['Parch']
df_test['FamilySize']=df_test['SibSp']+df_train['Parch']

#Convert Sex string to int (1 =  male, 0 = female)
df_train['Sex'] = df_train['Sex'].map(lambda x: 1 if x == 'male' else 0)
df_test['Sex'] = df_test['Sex'].map(lambda x: 1 if x == 'male' else 0)

##Convert Deck string to int (1 =  Cabins, 0 = Below)
df_train['Deck'] = df_train['Deck'].map(lambda x: 0 if pd.isnull(x) else 1)
df_test['Deck'] = df_test['Deck'].map(lambda x: 0 if pd.isnull(x) else 1)

# %% [markdown]
# <h1><b>BASELINE ANALYSIS OF DATA</b></h1>

# %%
#Survival from Sex, Pclass
pac_group = df_train.groupby(['Sex', 'Pclass']).mean()
pac_group['Survived'].plot.bar()

# %%
#Survival from Sex, Age

#sa_group = df_train.groupby(['Sex', 'Age']).mean()
#sa_group['Survived'].plot.bar()

#This data is too large

#Fixed issue with above data by using np.arrange

age_group = pd.cut(df_train["Age"], np.arange(0, 100, 10))
sa_group = df_train.groupby(['Sex', age_group]).mean()
sa_group['Survived'].plot.bar()

# %%
#Survival from Sex, FamilySize
sfs_group = df_train.groupby(['Sex', 'FamilySize']).mean()
sfs_group['Survived'].plot.bar()

# %%
#Survival from Deck location
loc_group = df_train.groupby(['Deck']).mean()
loc_group['Survived'].plot.bar()

# %%
#Survival from Pclass, Age
sfs_group = df_train.groupby(['Pclass', age_group]).mean()
sfs_group['Survived'].plot.bar()

# %% [markdown]
# <h1><b>FIX DATA AND REMOVE UNUSED COLUMNS</b></h1>

# %%
#Remove columns I don't plan to use
df_drop = df_train.drop(['Name', 'SibSp','Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'], axis=1)
df_Tdrop = df_test.drop(['Name', 'SibSp','Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'], axis=1)

#Useful function I found online to help prevent errors in my Decision Tree
#Fills forward for empty data 
df_drop.fillna(method='ffill', inplace=True)
df_Tdrop.fillna(method='ffill', inplace=True)

# %% [markdown]
# <h1><b>BEGIN TRAINING</b></h1>

# %%
#Our initial data is all passengers for training
X = df_drop.drop(['Survived'], 1).values
#Our actual data of passengers that survived
Y = df_drop['Survived'].values

#Can mess with test_size
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

#Can change the max_depth to see optimal depth
df_dt = DecisionTreeClassifier(max_depth=9, random_state=42)

df_dt.fit(X_train, Y_train)
df_dt.score(X_test, Y_test)
# Out:
# 0.77094972067039103

# %%
#K folds process learned in class
skfolds = StratifiedKFold(n_splits=15, random_state=42)

for train_index, test_index in skfolds.split(X, Y):
    clone_classifier = clone(df_dt)
    X_train_folds = X[train_index]
    Y_train_folds = Y[train_index]
    X_test_fold = X[test_index]
    Y_test_fold = Y[test_index]
    
clone_classifier.fit(X_train_folds, Y_train_folds)
y_pred = clone_classifier.predict(X_test_fold)
n_correct = sum(y_pred == Y_test_fold)
print (n_correct/len(y_pred))
# Out:
# 0.844827586207

# %%
df_Tdrop['Survived'] = clone_classifier.predict(df_Tdrop)
df_Tdrop.head()
df_Tdrop[['PassengerId', 'Survived']].to_csv('DTreeSKFold.csv', index=False)
print (df_Tdrop[['PassengerId', 'Survived']].head(20))
# Out:
#     PassengerId  Survived
# 0           892         0
# 1           893         1
# 2           894         0
# 3           895         0
# 4           896         0
# 5           897         0
# 6           898         0
# 7           899         0
# 8           900         0
# 9           901         0
# 10          902         0
# 11          903         0
# 12          904         1
# 13          905         0
# 14          906         1
# 15          907         1
# 16          908         0
# 17          909         0
# 18          910         0
# 19          911         1

# %%
df_Tdrop['Survived'].mean()
# Out:
# 0.24880382775119617
